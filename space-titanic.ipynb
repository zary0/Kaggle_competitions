# %% [markdown]
# <a href="https://www.kaggle.com/code/ryotaozawa/space-titanic?scriptVersionId=113069600" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spaceship-titanic/sample_submission.csv
# /kaggle/input/spaceship-titanic/train.csv
# /kaggle/input/spaceship-titanic/test.csv

# %%
import random

# %%
df = pd.read_csv('/kaggle/input/spaceship-titanic/train.csv')

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
Y = df['Transported']

# %%
Y
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8688    False
# 8689    False
# 8690     True
# 8691    False
# 8692     True
# Name: Transported, Length: 8693, dtype: bool

# %%
X = df.drop(columns=['Name','Transported','Cabin'])

# %%
X.isnull().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# dtype: int64

# %%
# Missing values handling and numeric inversion in HomePlanet
X['HomePlanet'] = X['HomePlanet'].replace('Europa','0')
X['HomePlanet'] = X['HomePlanet'].replace('Earth','1')
X['HomePlanet'] = X['HomePlanet'].replace('Mars','2')
X.loc[X['HomePlanet'].isnull(),['HomePlanet']] = random.randrange(3)

# %%
# Missing values handling and numeric inversion in CryoSleep
X['CryoSleep'] = X['CryoSleep'].replace('True','0')
X['CryoSleep'] = X['CryoSleep'].replace('False','1')
X.loc[X['CryoSleep'].isnull(),['CryoSleep']] = random.randrange(2)

# %%
# Missing values handling and numeric inversion in Destination
X['Destination'] = X['Destination'].replace('TRAPPIST-1e','0')
X['Destination'] = X['Destination'].replace('55 Cancri e','1')
X['Destination'] = X['Destination'].replace('PSO J318.5-22','2')
X.loc[X['Destination'].isnull(),['Destination']] = random.randrange(3)

# %%
#Missing values handling in Age
mean = X.mean()
X = X.fillna(mean)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression(max_iter=1000)

# %%
lr.fit(X,Y)
# Out:
# LogisticRegression(max_iter=1000)

# %%
df_test = pd.read_csv('/kaggle/input/spaceship-titanic/test.csv')

# %%
df_test.isnull().sum()
# Out:
# PassengerId       0
# HomePlanet       87
# CryoSleep        93
# Cabin           100
# Destination      92
# Age              91
# VIP              93
# RoomService      82
# FoodCourt       106
# ShoppingMall     98
# Spa             101
# VRDeck           80
# Name             94
# dtype: int64

# %%
X_test = df_test.drop(columns={'Name','Cabin'})

# %%
# Missing values handling and numeric inversion in HomePlanet
X_test['HomePlanet'] = X_test['HomePlanet'].replace('Europa','0')
X_test['HomePlanet'] = X_test['HomePlanet'].replace('Earth','1')
X_test['HomePlanet'] = X_test['HomePlanet'].replace('Mars','2')
X_test.loc[X_test['HomePlanet'].isnull(),['HomePlanet']] = random.randrange(3)

# %%
# Missing values handling and numeric inversion in CryoSleep
X_test['CryoSleep'] = X_test['CryoSleep'].replace('True','0')
X_test['CryoSleep'] = X_test['CryoSleep'].replace('False','1')
X_test.loc[X_test['CryoSleep'].isnull(),['CryoSleep']] = random.randrange(2)

# %%
# Missing values handling and numeric inversion in Destination
X_test['Destination'] = X_test['Destination'].replace('TRAPPIST-1e','0')
X_test['Destination'] = X_test['Destination'].replace('55 Cancri e','1')
X_test['Destination'] = X_test['Destination'].replace('PSO J318.5-22','2')
X_test.loc[X_test['Destination'].isnull(),['Destination']] = random.randrange(3)

# %%
#Missing values handling in Age
mean = X_test.mean()
X_test = X_test.fillna(mean)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
X_test.isnull().sum()
# Out:
# PassengerId     0
# HomePlanet      0
# CryoSleep       0
# Destination     0
# Age             0
# VIP             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# dtype: int64

# %%
Y_hat =pd.DataFrame(data = lr.predict(X_test),columns={'Transported'})

# %%
Passenger_df = pd.DataFrame(data = df_test['PassengerId'],columns={'PassengerId'})

# %%
submission_df = pd.concat([Passenger_df,Y_hat],axis=1).set_index('PassengerId')

# %%
submission_df.to_csv('/kaggle/working/submission.csv')
